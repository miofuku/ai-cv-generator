# %% [markdown]
# 外部考试通过的总人数随时间变化BestandenePrüfungen
# 外部考试总通过率随时间变化Bestandene\nPrüfungen / Prüfungs-\nteilnahmen
# 外部考试通过的女性人数随时间变化Bestandene\nPrüfungen
# 外部考试女性通过率随时间变化（自己/自己）
# Bestandene\nPrüfungen / Prüfungs-\nteilnahmen
# 通过女性占总通过人数的比率变化
# Bestandene\nPrüfungen / Bestandene\nPrüfungen
# 外部考试通过的男性人数随时间变化Bestandene\nPrüfungen
# 外部考试男性通过率随时间变化（自己/自己）
# Bestandene\nPrüfungen / Prüfungs-\nteilnahmen
# 通过男性占总通过人数的比率变化
# Bestandene\nPrüfungen / Bestandene\nPrüfungen

# %%
from common import pd, plt, np, file_path

# %% [markdown]
# ### 21211-05: Abschlussprüfungen mit Externenzulassung, Geschlecht, Prüfungserfolg, Ausbildungsbereiche - Zeitreihe
# 外部考试通过

# %%
sheet_name =  '21211-05'
df = pd.read_excel(file_path, sheet_name=sheet_name, header=[3, 4])
df = df.rename(columns={'Unnamed: 0_level_1': 'Beruf', 'Unnamed: 1_level_1': 'Jahr'})
df[('Ausbildungsbereich / Jahr', 'Beruf')] = df[('Ausbildungsbereich / Jahr', 'Beruf')].fillna(method='ffill')
groups = df.groupby(('Ausbildungsbereich / Jahr', 'Beruf'))
print(df.columns)
# Out:
# MultiIndex([('Ausbildungsbereich / Jahr',                 'Beruf'),
#             ('Ausbildungsbereich / Jahr',                  'Jahr'),
#             (                'Insgesamt', 'Prüfungs-\nteilnahmen'),
#             (                'Insgesamt', 'Bestandene\nPrüfungen'),
#             (                   'Frauen', 'Prüfungs-\nteilnahmen'),
#             (                   'Frauen', 'Bestandene\nPrüfungen'),
#             (                   'Männer', 'Prüfungs-\nteilnahmen'),
#             (                   'Männer', 'Bestandene\nPrüfungen')],
#            )
# C:\Users\Chenweiduo\AppData\Local\Temp\ipykernel_14436\3713257803.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[('Ausbildungsbereich / Jahr', 'Beruf')] = df[('Ausbildungsbereich / Jahr', 'Beruf')].fillna(method='ffill')

# %% [markdown]
# #### 1.External exam passings over time
#
# 外部考试通过的总人数随时间变化

# %%
plt.figure(figsize=(8, 6))

for group_name, group_data in groups:
    plt.plot(group_data[('Ausbildungsbereich / Jahr','Jahr')], group_data[('Insgesamt', 'Bestandene\nPrüfungen')], marker='o', label=group_name)

plt.title('External exam passings over time')
plt.xlabel('Year')
plt.ylabel('Number')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2.External exam pass rate over time
#
# 外部考试总通过率随时间变化

# %%
plt.figure(figsize=(10, 6))

for group_name, group_data in groups:
    plt.plot(group_data[('Ausbildungsbereich / Jahr','Jahr')], group_data[('Insgesamt', 'Bestandene\nPrüfungen')] / group_data[('Insgesamt', 'Prüfungs-\nteilnahmen')] , marker='o', label=group_name)

plt.title('External exam pass rate over time')
plt.xlabel('Year')
plt.ylabel('rates')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 3.External exam passings for women over time
#
# 外部考试通过的女性人数随时间变化

# %%
plt.figure(figsize=(8, 6))

for group_name, group_data in groups:
    plt.plot(group_data[('Ausbildungsbereich / Jahr','Jahr')], group_data[('Frauen', 'Bestandene\nPrüfungen')], marker='o', label=group_name)

plt.title('External exam passings for women over time')
plt.xlabel('Year')
plt.ylabel('Number')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4.External exam pass rate for women over time
#
# 外部考试女性通过率随时间变化（自己/自己）

# %%
plt.figure(figsize=(10, 6))

for group_name, group_data in groups:
    plt.plot(group_data[('Ausbildungsbereich / Jahr','Jahr')], group_data[('Frauen', 'Bestandene\nPrüfungen')] / group_data[('Frauen', 'Prüfungs-\nteilnahmen')] , marker='o', label=group_name)

plt.title('External exam pass rate for women over time')
plt.xlabel('Year')
plt.ylabel('rates')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 5.Ratio of women in total external exam passings
#
# 通过女性占总通过人数的比率变化

# %%
plt.figure(figsize=(10, 6))

for group_name, group_data in groups:
    plt.plot(group_data[('Ausbildungsbereich / Jahr','Jahr')], group_data[('Frauen', 'Bestandene\nPrüfungen')] / group_data[('Insgesamt', 'Bestandene\nPrüfungen')] , marker='o', label=group_name)

plt.title('Ratio of women in total external exam passings')
plt.xlabel('Year')
plt.ylabel('rates')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 6.External exam passings for men over time
#
# 外部考试通过的男性人数随时间变化

# %%
plt.figure(figsize=(8, 6))

for group_name, group_data in groups:
    plt.plot(group_data[('Ausbildungsbereich / Jahr','Jahr')], group_data[('Männer', 'Bestandene\nPrüfungen')], marker='o', label=group_name)

plt.title('External exam passings for men over time')
plt.xlabel('Year')
plt.ylabel('Number')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 7.External exam pass rate for men over time
#
# 外部考试男性通过率随时间变化（自己/自己）

# %%
plt.figure(figsize=(10, 6))

for group_name, group_data in groups:
    plt.plot(group_data[('Ausbildungsbereich / Jahr','Jahr')], group_data[('Männer', 'Bestandene\nPrüfungen')] / group_data[('Männer', 'Prüfungs-\nteilnahmen')] , marker='o', label=group_name)

plt.title('External exam pass rate for men over time')
plt.xlabel('Year')
plt.ylabel('rates')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 8.Ratio of men in total external exam passings
#
# 通过男性占总通过人数的比率变化

# %%
plt.figure(figsize=(10, 6))

for group_name, group_data in groups:
    plt.plot(group_data[('Ausbildungsbereich / Jahr','Jahr')], group_data[('Männer', 'Bestandene\nPrüfungen')] / group_data[('Insgesamt', 'Bestandene\nPrüfungen')] , marker='o', label=group_name)

plt.title('Ratio of men in total external exam passings')
plt.xlabel('Year')
plt.ylabel('rates')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
